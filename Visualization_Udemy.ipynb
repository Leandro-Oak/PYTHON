# %% [markdown]
# <a href="https://colab.research.google.com/github/Leandro-Oak/PYTHON/blob/master/Visualization_Udemy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Intro to Seaborn - It is built on top of Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=10,8

# %%
#Demografic data

data = pd.read_csv("/content/Demographic.csv")
data.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers','IncomeGroup']
data.head()
# Out:
#             CountryName CountryCode  ...  InternetUsers          IncomeGroup
# 0                 Aruba         ABW  ...           78.9          High income
# 1           Afghanistan         AFG  ...            5.9           Low income
# 2                Angola         AGO  ...           19.1  Upper middle income
# 3               Albania         ALB  ...           57.2  Upper middle income
# 4  United Arab Emirates         ARE  ...           88.0          High income
#
# [5 rows x 5 columns]

# %% [markdown]
# ----------------------------------------------------

# %%
#Movies dataset

movies =pd.read_csv("/content/MovieRatings.csv")
movies.columns = ['Film', 'Genre', 'CriticRatings', 'AudienceRatings',
       'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  ...  BudgetMillions  Year
# 0  (500) Days of Summer      Comedy  ...               8  2009
# 1            10,000 B.C.  Adventure  ...             105  2008
# 2             12 Rounds      Action  ...              20  2009
# 3              127 Hours  Adventure  ...              18  2010
# 4              17 Again      Comedy  ...              20  2009
#
# [5 rows x 6 columns]

# %%
movies.isnull().sum()
# Out:
# Film               0
# Genre              0
# CriticRatings      0
# AudienceRatings    0
# BudgetMillions     0
# Year               0
# dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
movies.groupby("Year")["Film"].count()
# Out:
# Year
# 2007     79
# 2008    122
# 2009    116
# 2010    119
# 2011    123
# Name: Film, dtype: int64

# %%
#change datatypes to category

movies["Film"] = movies["Film"].astype("category")
movies["Genre"] = movies["Genre"].astype("category")
movies["Year"] = movies["Year"].astype("category")

# %%
movies.Year.unique()
# Out:
# [2009, 2008, 2010, 2007, 2011]
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
#differnt way to select categorical columns
movies['Genre'].cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# ##Keyword arguments

# %%
#Keyword argument(named argument ex. size=8) are the configuration features inside the function.
#for more info watch the video on Udemy - python for data science 



#Seaborn documentation
#https://seaborn.pydata.org/generated/seaborn.lmtplot.html
#color and size reference
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html



#change the marker color and size with scatter_kws={"s":200}
vis4 = sns.lmplot(x='InternetUsers', y='BirthRate', data=data, fit_reg=False,\
                  hue='IncomeGroup', size=8,scatter_kws={"s":100})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ##SEABORN LIBRARY
# ###https://seaborn.pydata.org/examples/index.html
#
# ##Set style and themes
# ###https://seaborn.pydata.org/api.html

# %% [markdown]
# ##Distribution

# %%
vis1 = sns.distplot(data["InternetUsers"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
vis1 = sns.distplot(data["BirthRate"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Histograms

# %%
#Used to understand distributions of a series on your data

movies_hist = sns.distplot(movies['BudgetMillions'],bins=15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Distplot and displot disply the data in a different way

movies_hist2 = sns.displot(movies['BudgetMillions'],bins=15)

# %%
movies_hist2 = sns.displot(movies['AudienceRatings'],bins=15)

# %%
#the critics distribution is more uniform


movies_hist2 = sns.displot(movies['CriticRatings'],bins=15)

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions
# count     559.000000       559.000000      559.000000
# mean       47.309481        58.744186       50.236136
# std        26.413091        16.826887       48.731817
# min         0.000000         0.000000        0.000000
# 25%        25.000000        47.000000       20.000000
# 50%        46.000000        58.000000       35.000000
# 75%        70.000000        72.000000       65.000000
# max        97.000000        96.000000      300.000000

# %% [markdown]
# ##Stacked Distribution / Histograms

# %%
#version 1
#Graph with filters of two columns
#And show them on top of each other


plt.hist(movies[movies['Genre']=="Action"].BudgetMillions,bins=15 )
plt.hist(movies[movies['Genre']=="Drama"].BudgetMillions,bins=15)
plt.hist(movies[movies['Genre']=="Romance"].BudgetMillions,bins=15)
plt.show()

# %%
#Version 2
#Side side of each other

plt.hist([movies[movies['Genre']=="Action"].BudgetMillions,\
         movies[movies['Genre']=="Drama"].BudgetMillions,\
         movies[movies['Genre']=="Romance"].BudgetMillions],bins=15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#Version 3
#Stacked on top of each other


plt.hist([movies[movies['Genre']=="Action"].BudgetMillions,\
         movies[movies['Genre']=="Drama"].BudgetMillions],bins=15, stacked = True,)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#Version 4
# Using For looping to define multiple Genre
filter= []
mylabels = []
for x in movies['Genre'].cat.categories:
  filter.append(movies[movies['Genre']== x].BudgetMillions)
  mylabels.append(x)


h = plt.hist(filter, bins=30, stacked=True, rwidth=3, label=mylabels)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
movies.head()
# Out:
#                     Film      Genre  ...  BudgetMillions  Year
# 0  (500) Days of Summer      Comedy  ...               8  2009
# 1            10,000 B.C.  Adventure  ...             105  2008
# 2             12 Rounds      Action  ...              20  2009
# 3              127 Hours  Adventure  ...              18  2010
# 4              17 Again      Comedy  ...              20  2009
#
# [5 rows x 6 columns]

# %% [markdown]
# ##Boxplot

# %%
vis3 = sns.boxplot(data=data,x='IncomeGroup', y='BirthRate')

# %%
vis3 = sns.boxplot(data=movies,x="Genre", y="CriticRatings")

# %%
#Filtering inside the data parameter
vis4 = vis3 = sns.boxplot(data=movies[movies["Genre"]=="Drama"],x="Year", y="CriticRatings")

# %% [markdown]
# ##Violin PLOT

# %%
vio =  sns.violinplot(data=movies[movies["Genre"]=="Drama"],x="Year", y="CriticRatings")

# %%
vio2 = sns.violinplot(data=movies,x="Genre", y="CriticRatings")

# %% [markdown]
# ##Linear Model Plot

# %%
#Plot internet users by rate

#It Will insert a line if the parameter fit_reg is true
#hue is for color

vis4 = sns.lmplot(x='InternetUsers', y='BirthRate', data=data, fit_reg=True,hue='IncomeGroup', size=7, aspect=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Movies relationship between CriticRating and AudienceRatings and AudienceRatings vs budget

movies_viz = sns.lmplot(data=movies, x="CriticRatings", y="AudienceRatings", size=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
movies[["CriticRatings", "AudienceRatings"]].corr()
# Out:
#                  CriticRatings  AudienceRatings
# CriticRatings         1.000000         0.654803
# AudienceRatings       0.654803         1.000000

# %%
movies_viz = sns.lmplot(data=movies, x="BudgetMillions", y="AudienceRatings", size=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
movies[["CriticRatings", "BudgetMillions"]].corr()
# Out:
#                 CriticRatings  BudgetMillions
# CriticRatings        1.000000        0.014071
# BudgetMillions       0.014071        1.000000

# %% [markdown]
# ##Scatterplot

# %% [markdown]
# ###It’s common practice to place the independent metric along the horizontal or x-axis and the dependent variable along the y-axis. It’s not wrong to invert these, but it might be unexpected causing an initial bit of confusion

# %%
vis5 = sns.scatterplot(x='InternetUsers', y='BirthRate',data=data,hue='IncomeGroup',)

# %% [markdown]
# ##JoinPlot

# %%
#The joinPlot is a comination of scatterplot and histogram

#Version 1

movies_viz_join = sns.jointplot(data=movies, x="CriticRatings", y="AudienceRatings", size=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Version2 
#Changed the keyword argument Kind


movies_viz_join2 = sns.jointplot(data=movies, x="CriticRatings", y="AudienceRatings", size=8, kind='hex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions
# count     559.000000       559.000000      559.000000
# mean       47.309481        58.744186       50.236136
# std        26.413091        16.826887       48.731817
# min         0.000000         0.000000        0.000000
# 25%        25.000000        47.000000       20.000000
# 50%        46.000000        58.000000       35.000000
# 75%        70.000000        72.000000       65.000000
# max        97.000000        96.000000      300.000000

# %% [markdown]
# ##KDE PLOT (Kernel Density Estimate)

# %%
movies.head()
# Out:
#                     Film      Genre  ...  BudgetMillions  Year
# 0  (500) Days of Summer      Comedy  ...               8  2009
# 1            10,000 B.C.  Adventure  ...             105  2008
# 2             12 Rounds      Action  ...              20  2009
# 3              127 Hours  Adventure  ...              18  2010
# 4              17 Again      Comedy  ...              20  2009
#
# [5 rows x 6 columns]

# %%
#Same idea of a ScatterPlot but show the density of the data


k1 = sns.kdeplot(movies['CriticRatings'],movies['AudienceRatings'], shade=True,\
                 shade_lowest=False, cmap='Reds')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#version 2 
sns.kdeplot(movies['CriticRatings'],movies['AudienceRatings'], cmap='Reds')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(data=movies, x='CriticRatings',y='AudienceRatings', size=7, hue='Genre')

# %%
sns.lmplot(data=movies, x='CriticRatings',y='AudienceRatings', size=7, aspect=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
movies[['CriticRatings','AudienceRatings']].corr()
# Out:
#                  CriticRatings  AudienceRatings
# CriticRatings         1.000000         0.654803
# AudienceRatings       0.654803         1.000000

# %% [markdown]
# ##Bar Chart

# %%
bar = sns.barplot(data=movies, x = 'Year', y='BudgetMillions')

# %%
bar1 = sns.barplot(data=movies, x = 'Genre', y='BudgetMillions')

# %%
#bar3 = sns.barplot(data=movies, x = 'Year', y='Film', estimator=count_nonzero)

# %% [markdown]
# ##Countplot

# %%
bar2 = sns.countplot(data=movies, x='Year')

# %% [markdown]
# ##SubPLots

# %%
sns.set_style("dark")
sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.kdeplot(movies['BudgetMillions'],movies['CriticRatings'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
###subplots

f, axes = plt.subplots(2,3, figsize=(25,15))
a = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax=axes[0,0])
b = sns.kdeplot(movies['BudgetMillions'],movies['CriticRatings'],ax=axes[0,1])
c = sns.scatterplot(data=movies, x='CriticRatings',y='AudienceRatings', hue='Genre',ax=axes[0,2])
d = sns.barplot(data=movies, x = 'Year', y='BudgetMillions',ax=axes[1,0])
#e = sns.jointplot(data=movies, x="CriticRatings", y="AudienceRatings",ax=axes[1,2])
#f = sns.displot(movies['BudgetMillions'],ax=axes[1,1])
vis3 = sns.boxplot(data=movies,x="Genre", y="CriticRatings",ax=axes[1,1])
vio =  sns.violinplot(data=movies, x="Genre", y="CriticRatings",ax=axes[1,2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Facet Grid

# %%
#Facegrid with Scatterplot
g = sns.FacetGrid(movies, row="Genre", col='Year', hue='Genre')
g = g.map(plt.scatter, "CriticRatings", "AudienceRatings")

# %%
#Facegrid with histogram
g = sns.FacetGrid(movies, row="Genre", col='Year', hue='Genre')
g = g.map(plt.hist, "CriticRatings")

# %%
#Facegrid with Scatterplot with a keyword argument to change
g = sns.FacetGrid(movies, row="Genre", col='Year', hue='Genre')
kws = dict (s=50, linewidth = 0.5, edgecolor= 'black')
g = g.map(plt.scatter, "CriticRatings", "AudienceRatings", **kws)
